# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
path = r'/content/drive/My Drive/Colab Notebooks/'

# %%
# %cd /content/drive/My Drive/Colab Notebooks/Realtime-Action-Recognition/

# %%
#!sudo apt-get install -y swig

# %%
# !pip uninstall tensorflow-gpu==1.13.1 -y
# !pip uninstall tensorflow -y
# !pip install tensorflow-gpu==1.13.1
# !pip install scikit-learn==0.21.3
# !pip install simplejson
# !pip install tf_pose

# %%
#!git clone https://github.com/felixchenfy/Realtime-Action-Recognition.git

# %%
#!git clone https://github.com/felixchenfy/ildoonet-tf-pose-estimation
#!mv ildoonet-tf-pose-estimation tf-pose-estimation

# %%
# %cd tf-pose-estimation

# %%
# %cd tf_pose/pafprocess
# !swig -python -c++ pafprocess.i && python3 setup.py build_ext --inplace
# !python setup.py install
# !pip install -U numpy

# %%
# !pip3 install -r requirements.txt

# %%
# %cd tf-pose-estimation

# %%
#!python run.py --model=mobilenet_v2_large --resize=432x368 --image=./images/p1.jpg

# %%
# %cd src/

# %%
# !python s5_test.py \
    --model_path model/trained_classifier.pickle \
    --data_type video \
    --data_path data_test/trimmed_Cam4.mp4 \
    --output_folder output

# %%
#!pip install tensorflow-gpu==1.13.1
